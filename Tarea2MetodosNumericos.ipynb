# %% [markdown]
# <a href="https://colab.research.google.com/github/Ian-G27/Clase_MetodosNumericos/blob/main/Tarea2MetodosNumericos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Buendia Alvarez Ian Diego

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

taylor_serie = sp.series(f_x, x, 1, 5)  #Esta linea nos ayuda a calcular la serie de taylor de la funcion f(x)=ln(x)
taylor_serie = taylor_serie.removeO()  #Esto es para que la serie de Taylor generada por sympy incluya un termino de orden para que indique hasta donde se va a truncar la serie auqnue este termino es mas informativo que funcional, asi que se elimina con removeO() para obtener solo el polinomio de la serie
print("Serie de Taylor truncada de f(x) = ln(x) alrededor de x0 = 1:")
print(taylor_serie)
taylor_funcion = sp.lambdify(x, taylor_serie, "numpy") #Aqui nos va a ayudar a convertir expresiones simbólicas en funciones numericas para que puedan ser evaluadas para distintos valores de x
f_x_func = sp.lambdify(x, f_x, "numpy")
x_vals = np.linspace(0.5, 2, 400)     #Aqui solo voy a definir el rango de valores para graficar
f_vals = f_x_func(x_vals)             #aqui evalua la función f(x)= ln(x) asi obteniendo todos los resultados
taylor_vals = taylor_funcion(x_vals)   #Evalua el polinomio de Taylor en los mismos valores de x y almacena los resultados
plt.plot(x_vals, f_vals, label='f(x) = ln(x)', color='blue')   #Aqui los valores calculados de la funcion f(x)=ln(x) esta representados por una linea de color azul
plt.plot(x_vals, taylor_vals, label='Polinomio de Taylor (De orden 4)', linestyle='--', color='red')  #y aqui los valores del polinomio de taylor esta representada por una linea roja discontinua
#Etiquetas y titulo de la grafica que sera imprimida
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Aproximacion de ln(x) con la serie de Taylor de cuarto orden')
plt.axvline(x=1, color='green', linestyle=':', label='x0 = 1')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Serie de Taylor truncada de f(x) = ln(x) alrededor de x0 = 1:
# x - (x - 1)**4/4 + (x - 1)**3/3 - (x - 1)**2/2 - 1
